# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['axes.unicode_minus'] = False
plt.rc('font', family='NanumBarunGothic')

# %%
# !pip install selenium > /dev/null

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import time
from urllib.parse import quote

# %%
chromedriver = "C:\WorkspaceB/chromedriver.exe"
driver = webdriver.Chrome(chromedriver)

# %%
insta_url = 'http://koreanfood.rda.go.kr/kfi/mgnNewmealinfoMealquery/list'
driver.get(insta_url)
time.sleep(2)

# %%
search = '현미밥'
input = driver.find_element_by_css_selector('#eumsikName')
input.clear()
input.send_keys(search)

# %%
driver.find_element_by_css_selector('#search > div.right > div.dsFood-control > div.dsf-right > a').click()
time.sleep()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-8e00706d35ae> in <module>
#       1 driver.find_element_by_css_selector('#search > div.right > div.dsFood-control > div.dsf-right > a').click()
# ----> 2 time.sleep()
#
# TypeError: sleep() takes exactly one argument (0 given)
